# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
with open('data_sps_4D.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
with open('data_sps_4D_test.pkl', 'rb') as f:
    data_test = pickle.load(f)

# %%
data.keys()
# Out:
# dict_keys(['x', 'px', 'y', 'py'])

# %%
data_test.keys()
# Out:
# dict_keys(['x', 'px', 'y', 'py'])

# %%
data['x'].shape, data['px'].shape, data['y'].shape, data['py'].shape
# Out:
# ((10000, 1000), (10000, 1000), (10000, 1000), (10000, 1000))

# %%
data_test['x'].shape, data_test['px'].shape, data_test['y'].shape, data_test['py'].shape
# Out:
# ((1296, 1000), (1296, 1000), (1296, 1000), (1296, 1000))

# %%
plt.plot(data['x'][:, 0] * 1000, data['y'][:, 0] * 1000, '.', markersize=1, color='C0')
plt.grid()
plt.xlabel('x [mm]')
# plt.ylabel(r'$p_x$')
plt.ylabel('y [mm]')
# Out:
# Text(0, 0.5, 'y [mm]')

# %%
plt.plot(data_test['x'][:, 0] * 1000, data_test['y'][:, 0] * 1000, '.', markersize=1, color='C0')
plt.grid()
plt.xlabel('x [mm]')
# plt.ylabel(r'$p_x$')
plt.ylabel('y [mm]')
# Out:
# Text(0, 0.5, 'y [mm]')

# %%
import torch
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

from models import GSympNet

# %%
# Hyperparameters
dim = 4
layers = 9
width = 20
activation = torch.sigmoid
epochs = 100
batch_size = 64
learning_rate = 1e-3

# %%
# # x_xp_data_list = [np.array([data['x'][i, :], data['px'][i, :]]).T for i in range(data['x'].shape[0])]
# x_xp_data_list = [np.array([data['x'][i, :], data['px'][i, :]]).T for i in range(700)]
# x_xp_data = np.vstack(x_xp_data_list)

# %%
def min_max_normalize(arr, min_val=None, max_val=None):
    """
    Min-max normalize a numpy array or torch tensor of shape (N, 2) to range [-1, 1].
    If min_val and max_val are not provided, compute from arr along axis=0.
    Returns normalized array, min_val, and max_val.
    """
    if min_val is None:
        min_val = arr.min(axis=0, keepdims=True)
    if max_val is None:
        max_val = arr.max(axis=0, keepdims=True)
    normalized = 2 * (arr - min_val) / (max_val - min_val) - 1
    return normalized, min_val, max_val

def min_max_denormalize(arr, min_val, max_val):
    """
    Denormalize a numpy array or torch tensor of shape (N, 2) from range [-1, 1]
    back to the original range defined by min_val and max_val.
    """
    return (arr + 1) / 2 * (max_val - min_val) + min_val

# %%
data['x'].shape
# Out:
# (10000, 1000)

# %%
# Plot the train and test particles in (x, y) space
plt.figure(figsize=(8,6))
plt.scatter(data['x'][:,0] * 1000, data['y'][:,0] * 1000, s=10, color='C0', label='Train')
# plt.scatter(x_val[:, 0] * 1000, y_val[:, 0] * 1000, s=10, color='C2', label='Validation')
plt.scatter(data_test['x'][:,0] * 1000, data_test['y'][:,0] * 1000, s=10, color='C1', label='Test')
plt.xlabel('x [mm]')
plt.ylabel('y [mm]')
plt.title('Train and Test Particles in (x, y) Space')
plt.legend()
plt.grid()
plt.show()

# %%
# Plot the train and test particles in (x, px) space
plt.figure(figsize=(8,6))
plt.scatter(data['x'][:,0] * 1000, data['px'][:,0] * 1000, s=10, color='C0', label='Train')
# plt.scatter(x_val[:, 0] * 1000, y_val[:, 0] * 1000, s=10, color='C2', label='Validation')
plt.scatter(data_test['x'][:,0] * 1000, data_test['px'][:,0] * 1000, s=10, color='C1', label='Test')
plt.xlabel('x [mm]')
plt.ylabel('px [mrad]')
plt.title('Train and Test Particles in (x, px) Space')
plt.legend()
plt.grid()
plt.show()

# %%
# Plot the train and test particles in (y, py) space
plt.figure(figsize=(8,6))
plt.scatter(data['y'][:,0] * 1000, data['py'][:,0] * 1000, s=10, color='C0', label='Train')
# plt.scatter(x_val[:, 0] * 1000, y_val[:, 0] * 1000, s=10, color='C2', label='Validation')
plt.scatter(data_test['y'][:,0] * 1000, data_test['py'][:,0] * 1000, s=10, color='C1', label='Test')
plt.xlabel('y [mm]')
plt.ylabel('py [mrad]')
plt.title('Train and Test Particles in (x, py) Space')
plt.legend()
plt.grid()
plt.show()

# %%
np.random.seed(42)  # For reproducibility

num_particles = data['x'].shape[0]
train_size = 100
val_fraction = 0.2  # 20% for validation
val_size = int(train_size * val_fraction)

# Randomly select indices for training particles
train_indices = np.random.choice(num_particles, size=train_size, replace=False)

# Select val_size number of particles from the remaining indices for validation
remaining_indices = np.setdiff1d(np.arange(num_particles), train_indices)
val_indices = np.random.choice(remaining_indices, size=val_size, replace=False)

# indices to select train particles
x_train = data['x'][train_indices, :]
px_train = data['px'][train_indices, :]
y_train = data['y'][train_indices, :]
py_train = data['py'][train_indices, :]
x_val = data['x'][val_indices, :]
px_val = data['px'][val_indices, :]
y_val = data['y'][val_indices, :]
py_val = data['py'][val_indices, :]

# x_test = data['x'][test_indices, :]
# px_test = data['px'][test_indices, :]
# y_test = data['y'][test_indices, :]
# py_test = data['py'][test_indices, :]

x_test = data_test['x'][:, :]
px_test = data_test['px'][:, :]
y_test = data_test['y'][:, :]
py_test = data_test['py'][:, :]

# Plot the train and test particles in (x, y) space
plt.figure(figsize=(8,6))
plt.scatter(x_train[:, 0] * 1000, y_train[:, 0] * 1000, s=10, color='C0', label='Train')
plt.scatter(x_val[:, 0] * 1000, y_val[:, 0] * 1000, s=10, color='C2', label='Validation')
plt.scatter(x_test[:, 0] * 1000, y_test[:, 0] * 1000, s=10, color='C1', label='Test')
plt.xlabel('x [mm]')
plt.ylabel('y [mm]')
plt.title('Train and Test Particles in (x, y) Space')
plt.legend()
plt.grid()
plt.show()

# %%
# Plot the train and test particles in (x, px) space
plt.figure(figsize=(8,6))
plt.scatter(x_train[:, 0] * 1000, px_train[:, 0] * 1000, s=10, color='C0', label='Train')
plt.scatter(x_val[:, 0] * 1000, px_val[:, 0] * 1000, s=10, color='C2', label='Validation')
plt.scatter(x_test[:, 0] * 1000, px_test[:, 0] * 1000, s=10, color='C1', label='Test')
plt.xlabel('x [mm]')
plt.ylabel('y [mm]')
plt.title('Train and Test Particles in (x, px) Space')
plt.legend()
plt.grid()
plt.show()

# %%
# Plot the train and test particles in (y, py) space
plt.figure(figsize=(8,6))
plt.scatter(y_train[:, 0] * 1000, py_train[:, 0] * 1000, s=10, color='C0', label='Train')
plt.scatter(y_val[:, 0] * 1000, py_val[:, 0] * 1000, s=10, color='C2', label='Validation')
plt.scatter(y_test[:, 0] * 1000, py_test[:, 0] * 1000, s=10, color='C1', label='Test')
plt.xlabel('x [mm]')
plt.ylabel('y [mm]')
plt.title('Train and Test Particles in (x, px) Space')
plt.legend()
plt.grid()
plt.show()

# %%
x_train.shape, px_train.shape, x_val.shape, px_val.shape, x_test.shape, px_test.shape, y_train.shape, py_train.shape, y_val.shape, py_val.shape, y_test.shape, py_test.shape
# Out:
# ((100, 1000),
#  (100, 1000),
#  (20, 1000),
#  (20, 1000),
#  (1296, 1000),
#  (1296, 1000),
#  (100, 1000),
#  (100, 1000),
#  (20, 1000),
#  (20, 1000),
#  (1296, 1000),
#  (1296, 1000))

# %%
num_turns = 1000
train_data_list = [np.array([x_train[i, :num_turns+1], y_train[i, :num_turns+1], px_train[i, :num_turns+1], py_train[i, :num_turns+1]]).T for i in range(x_train.shape[0])]
train_data = np.vstack(train_data_list)
val_data_list = [np.array([x_val[i, :num_turns+1], y_val[i, :num_turns+1], px_val[i, :num_turns+1], py_val[i, :num_turns+1]]).T for i in range(x_val.shape[0])]
val_data = np.vstack(val_data_list)

# %%
train_norm, min, max = min_max_normalize(train_data)
val_norm = min_max_normalize(val_data, min, max)[0]

# %%
input, output = train_norm[:-1], train_norm[1:]

# %%
input-output
# Out:
# array([[ 0.48726541, -0.03873205, -0.39926553, -0.78682207],
#        [-0.09067245,  0.40826228,  0.6221672 ,  0.66864466],
#        [-0.35443739, -0.68102432, -0.51326067, -0.38608549],
#        ...,
#        [ 0.89551737,  0.99042466,  0.46557638, -0.65790401],
#        [-0.98538099, -0.54544512,  0.27896067,  1.03455995],
#        [ 0.54319735,  0.01326176, -0.87408495, -1.17652151]],
#       shape=(99999, 4))

# %%
val_norm[:-1] - val_norm[1:]
# Out:
# array([[ 0.45797582, -0.61205721, -0.46878441, -0.64983283],
#        [-0.02044417,  0.84677606,  0.65217258,  0.28335842],
#        [-0.42669778, -0.88605706, -0.48774112,  0.1636585 ],
#        ...,
#        [-0.10934377, -0.7455434 , -0.31935805,  0.12218833],
#        [ 0.29851926,  0.60086345,  0.1548087 , -0.4587858 ],
#        [-0.32707848, -0.30867636,  0.09104619,  0.68548142]],
#       shape=(19999, 4))

# %%
train_x = torch.tensor(input, dtype=torch.float32)
train_y = torch.tensor(output, dtype=torch.float32)
val_x = torch.tensor(val_norm[:-1], dtype=torch.float32)
val_y = torch.tensor(val_norm[1:], dtype=torch.float32)

# %%
train_x.shape
# Out:
# torch.Size([99999, 4])

# %%
val_x.shape
# Out:
# torch.Size([19999, 4])

# %%
train_dataset = TensorDataset(train_x, train_y)
val_dataset = TensorDataset(val_x, val_y)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=20, shuffle=False)

# %%
model = GSympNet(dim, layers, width, activation)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = torch.nn.MSELoss()

# %%
train_loss_list = []
val_loss_list = []

model.train()

for epoch in range(epochs):
    total_loss = 0.0
    for x_batch, y_batch in train_loader:
        optimizer.zero_grad()
        pred = model(x_batch)
        loss = criterion(pred, y_batch)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * x_batch.size(0)
    avg_loss = total_loss / len(train_dataset)
    train_loss_list.append(avg_loss)
    # print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.10f}")
    
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for x_batch, y_batch in val_loader:
            pred = model(x_batch)
            loss = criterion(pred, y_batch)
            val_loss += loss.item() * x_batch.size(0)
    avg_val_loss = val_loss / len(val_dataset)
    val_loss_list.append(avg_val_loss)
    print(f"Epoch {epoch+1}/{epochs}, Train Loss: {avg_loss:.10f}, Validation Loss: {avg_val_loss:.10f}")
    
    model.train()
    
    # Real-time plot
    # if (epoch+1) % 1 == 0 or epoch == 0:
    #     clear_output(wait=True)
    #     plt.figure(figsize=(8,4))
    #     # plt.plot(losses)
    #     # plt.ylabel('Loss')
    #     plt.xlabel('Epoch')
    #     plt.plot(np.log10(avg_loss), label='Training Loss', color='C0')
    #     plt.plot(np.log10(avg_val_loss), label='Validation Loss', color='C1', linestyle='--')
    #     plt.ylabel('log10(Loss)')
    #     plt.title('Training Loss')
    #     plt.grid()
    #     plt.show()
        
# Save the list of losses to a file
with open('training_losses.npy', 'wb') as f:
    np.save(f, np.array(train_loss_list))
    
with open('validation_losses.npy', 'wb') as f:
    np.save(f, np.array(val_loss_list))
# Out:
# Epoch 1/100, Train Loss: 0.6927624515, Validation Loss: 0.6842377684
# Epoch 2/100, Train Loss: 0.5420916088, Validation Loss: 0.3315525205
# Epoch 3/100, Train Loss: 0.3392921646, Validation Loss: 0.2299160036
# Epoch 4/100, Train Loss: 0.0280888420, Validation Loss: 0.0035702588
# Epoch 5/100, Train Loss: 0.0022236961, Validation Loss: 0.0022065228
# Epoch 6/100, Train Loss: 0.0015657831, Validation Loss: 0.0016672886
# Epoch 7/100, Train Loss: 0.0012697713, Validation Loss: 0.0013861250
# Epoch 8/100, Train Loss: 0.0011033302, Validation Loss: 0.0012235576
# Epoch 9/100, Train Loss: 0.0009825952, Validation Loss: 0.0010402766
# Epoch 10/100, Train Loss: 0.0008803783, Validation Loss: 0.0010199330
# Epoch 11/100, Train Loss: 0.0007975215, Validation Loss: 0.0008559822
# Epoch 12/100, Train Loss: 0.0007287798, Validation Loss: 0.0007322266
# Epoch 13/100, Train Loss: 0.0006736536, Validation Loss: 0.0006312386
# Epoch 14/100, Train Loss: 0.0006287898, Validation Loss: 0.0005806805
# Epoch 15/100, Train Loss: 0.0005896543, Validation Loss: 0.0005371860
# Epoch 16/100, Train Loss: 0.0005642505, Validation Loss: 0.0005076084
# Epoch 17/100, Train Loss: 0.0005440706, Validation Loss: 0.0004919458
# Epoch 18/100, Train Loss: 0.0005322850, Validation Loss: 0.0004632692
# Epoch 19/100, Train Loss: 0.0005232568, Validation Loss: 0.0004611248
# Epoch 20/100, Train Loss: 0.0005152145, Validation Loss: 0.0004626200
# Epoch 21/100, Train Loss: 0.0005109819, Validation Loss: 0.0004412510
# Epoch 22/100, Train Loss: 0.0005041977, Validation Loss: 0.0004418957
# Epoch 23/100, Train Loss: 0.0005044050, Validation Loss: 0.0004364932
# Epoch 24/100, Train Loss: 0.0005022564, Validation Loss: 0.0004311321
# Epoch 25/100, Train Loss: 0.0004994603, Validation Loss: 0.0004351714
# Epoch 26/100, Train Loss: 0.0004955079, Validation Loss: 0.0004522832
# Epoch 27/100, Train Loss: 0.0004947437, Validation Loss: 0.0004352013
# Epoch 28/100, Train Loss: 0.0004928632, Validation Loss: 0.0004419048
# Epoch 29/100, Train Loss: 0.0004916042, Validation Loss: 0.0004650790
# Epoch 30/100, Train Loss: 0.0004911835, Validation Loss: 0.0004435246
# Epoch 31/100, Train Loss: 0.0004886433, Validation Loss: 0.0004234676
# Epoch 32/100, Train Loss: 0.0004875545, Validation Loss: 0.0004368687
# Epoch 33/100, Train Loss: 0.0004848395, Validation Loss: 0.0004317797
# Epoch 34/100, Train Loss: 0.0004864737, Validation Loss: 0.0004122343
# Epoch 35/100, Train Loss: 0.0004829888, Validation Loss: 0.0004196603
# Epoch 36/100, Train Loss: 0.0004820873, Validation Loss: 0.0004112257
# Epoch 37/100, Train Loss: 0.0004823293, Validation Loss: 0.0004154203
# Epoch 38/100, Train Loss: 0.0004830845, Validation Loss: 0.0004134452
# Epoch 39/100, Train Loss: 0.0004796971, Validation Loss: 0.0004089358
# Epoch 40/100, Train Loss: 0.0004805259, Validation Loss: 0.0004107996
# Epoch 41/100, Train Loss: 0.0004780164, Validation Loss: 0.0004656380
# Epoch 42/100, Train Loss: 0.0004806779, Validation Loss: 0.0004112955
# Epoch 43/100, Train Loss: 0.0004779557, Validation Loss: 0.0005347738
# Epoch 44/100, Train Loss: 0.0004772766, Validation Loss: 0.0004201198
# Epoch 45/100, Train Loss: 0.0004768832, Validation Loss: 0.0004171958
# Epoch 46/100, Train Loss: 0.0004754154, Validation Loss: 0.0004120429
# Epoch 47/100, Train Loss: 0.0004760969, Validation Loss: 0.0004379797
# Epoch 48/100, Train Loss: 0.0004736127, Validation Loss: 0.0004408422
# Epoch 49/100, Train Loss: 0.0004731998, Validation Loss: 0.0004414688
# Epoch 50/100, Train Loss: 0.0004748583, Validation Loss: 0.0004058603
# Epoch 51/100, Train Loss: 0.0004753872, Validation Loss: 0.0004185995
# Epoch 52/100, Train Loss: 0.0004725216, Validation Loss: 0.0004013359
# Epoch 53/100, Train Loss: 0.0004727473, Validation Loss: 0.0004277783
# Epoch 54/100, Train Loss: 0.0004745928, Validation Loss: 0.0004011962
# Epoch 55/100, Train Loss: 0.0004712269, Validation Loss: 0.0003997308
# Epoch 56/100, Train Loss: 0.0004722020, Validation Loss: 0.0004026964
# Epoch 57/100, Train Loss: 0.0004700733, Validation Loss: 0.0004205678
# Epoch 58/100, Train Loss: 0.0004695936, Validation Loss: 0.0003998625
# Epoch 59/100, Train Loss: 0.0004719094, Validation Loss: 0.0004061959
# Epoch 60/100, Train Loss: 0.0004702837, Validation Loss: 0.0004229657
# Epoch 61/100, Train Loss: 0.0004682710, Validation Loss: 0.0004565868
# Epoch 62/100, Train Loss: 0.0004697358, Validation Loss: 0.0003971031
# Epoch 63/100, Train Loss: 0.0004700703, Validation Loss: 0.0003992440
# Epoch 64/100, Train Loss: 0.0004695790, Validation Loss: 0.0004010974
# Epoch 65/100, Train Loss: 0.0004675241, Validation Loss: 0.0003984695
# Epoch 66/100, Train Loss: 0.0004678161, Validation Loss: 0.0003944530
# Epoch 67/100, Train Loss: 0.0004676152, Validation Loss: 0.0003969774
# Epoch 68/100, Train Loss: 0.0004677675, Validation Loss: 0.0004086030
# Epoch 69/100, Train Loss: 0.0004659411, Validation Loss: 0.0004513529
# Epoch 70/100, Train Loss: 0.0004672443, Validation Loss: 0.0004003046
# Epoch 71/100, Train Loss: 0.0004663161, Validation Loss: 0.0003945435
# Epoch 72/100, Train Loss: 0.0004694988, Validation Loss: 0.0003963080
# Epoch 73/100, Train Loss: 0.0004663309, Validation Loss: 0.0003930244
# Epoch 74/100, Train Loss: 0.0004670240, Validation Loss: 0.0004843816
# Epoch 75/100, Train Loss: 0.0004657159, Validation Loss: 0.0003971559
# Epoch 76/100, Train Loss: 0.0004673993, Validation Loss: 0.0005206742
# Epoch 77/100, Train Loss: 0.0004676928, Validation Loss: 0.0004116008
# Epoch 78/100, Train Loss: 0.0004659203, Validation Loss: 0.0003935738
# Epoch 79/100, Train Loss: 0.0004645310, Validation Loss: 0.0003974184
# Epoch 80/100, Train Loss: 0.0004656394, Validation Loss: 0.0004255764
# Epoch 81/100, Train Loss: 0.0004664546, Validation Loss: 0.0004229706
# Epoch 82/100, Train Loss: 0.0004658700, Validation Loss: 0.0005070995
# Epoch 83/100, Train Loss: 0.0004645781, Validation Loss: 0.0003987722
# Epoch 84/100, Train Loss: 0.0004659489, Validation Loss: 0.0003926117
# Epoch 85/100, Train Loss: 0.0004653073, Validation Loss: 0.0004275083
# Epoch 86/100, Train Loss: 0.0004669481, Validation Loss: 0.0003980016
# Epoch 87/100, Train Loss: 0.0004660650, Validation Loss: 0.0004082386
# Epoch 88/100, Train Loss: 0.0004626019, Validation Loss: 0.0004165041
# Epoch 89/100, Train Loss: 0.0004638810, Validation Loss: 0.0003917730
# Epoch 90/100, Train Loss: 0.0004650552, Validation Loss: 0.0003912219
# Epoch 91/100, Train Loss: 0.0004642734, Validation Loss: 0.0004464765
# Epoch 92/100, Train Loss: 0.0004643658, Validation Loss: 0.0004652515
# Epoch 93/100, Train Loss: 0.0004644972, Validation Loss: 0.0003907865
# Epoch 94/100, Train Loss: 0.0004630262, Validation Loss: 0.0004048824
# Epoch 95/100, Train Loss: 0.0004652658, Validation Loss: 0.0004001795
# Epoch 96/100, Train Loss: 0.0004636284, Validation Loss: 0.0004106616
# Epoch 97/100, Train Loss: 0.0004640731, Validation Loss: 0.0004349800
# Epoch 98/100, Train Loss: 0.0004644113, Validation Loss: 0.0003910377
# Epoch 99/100, Train Loss: 0.0004646571, Validation Loss: 0.0003916384
# Epoch 100/100, Train Loss: 0.0004622979, Validation Loss: 0.0004045095

# %%
torch.save(model.state_dict(),'sympnet_model_multiparticle_xy_fin.pt')

# %%
# Re-instantiate the model and load the saved weights
model = GSympNet(dim, layers, width, activation)
model.load_state_dict(torch.load('sympnet_model_multiparticle_xy_fin.pt'))
# Out:
# <All keys matched successfully>

# %%
init_test = np.array([x_test[:, 0], y_test[:,0], px_test[:, 0], py_test[:,0]]).T

# %%
# x_xp_init_test = np.array([data['x'][index, 700], data['px'][index, 700]]).T

# %%
# x_xp_init_test = x_xp_init_test.reshape(1, 2)
init_test.shape, init_test.dtype
# Out:
# ((1296, 4), dtype('float64'))

# %%
min.dtype
# Out:
# dtype('float64')

# %%
init_test_norm = min_max_normalize(init_test, min, max)[0]

# %%
init_test_tensor = torch.tensor(init_test_norm, dtype=torch.float32)

# %%
# x_xp_init_test_tensor = x_xp_init_test_tensor.unsqueeze(0)  # Add batch dimension
init_test_tensor.shape
# Out:
# torch.Size([1296, 4])

# %%
pred_init = model.predict(init_test_tensor, steps=999)

# %%
x_test.shape
# Out:
# (1296, 1000)

# %%
test = np.array([x_test[:, 1:], y_test[:, 1:], px_test[:, 1:], py_test[:, 1:]]).T

# %%
pred = min_max_denormalize(pred_init.detach().numpy(), min, max)

# %%
test.shape, pred.shape
# Out:
# ((999, 1296, 4), (1296, 999, 4))

# %%
index = 50
plt.plot(test[:, index, 0] * 1000, test[:, index, 2] * 1000, '.', markersize=1, color='C0')
plt.plot(pred[index, :, 0] * 1000, pred[index, :, 2] * 1000, '.', markersize=1, color='C1')
plt.grid()
plt.xlabel('x [mm]')
plt.ylabel(r'$p_x$')
# Out:
# Text(0, 0.5, '$p_x$')

# %%
plt.plot(test[:, index, 1] * 1000, test[:, index, 3] * 1000, '.', markersize=1, color='C0')
plt.plot(pred[index, :, 1] * 1000, pred[index, :, 3] * 1000, '.', markersize=1, color='C1')
plt.grid()
plt.xlabel('y [mm]')
plt.ylabel(r'$p_y$')
# Out:
# Text(0, 0.5, '$p_y$')

# %%
# Plot position and momentum over turns

def compare_pred_act_x(index, turns):
    plt.figure(figsize=(12, 5))
    plt.subplot(2, 1, 1)
    plt.plot(test[turns, index, 0], label='x', color='C0')
    plt.plot(pred[index, turns, 0].squeeze(), label='Predicted x', linestyle='--', color='C1')
    plt.title(f'Particle {index} Position Over Turns')
    plt.ylabel('x')
    plt.grid()
    plt.legend()

    plt.subplot(2, 1, 2)
    plt.plot(test[turns, index, 2], label='px', color='C0')
    plt.plot(pred[index, turns, 2].squeeze(), label='Predicted px', linestyle='--', color='C1')
    plt.title(f'Particle {index} Momentum Over Turns')
    plt.xlabel('Turn')
    plt.ylabel('px')
    plt.grid()
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
index = 30  # Change this to visualize different particles
turns = np.arange(100)

compare_pred_act_x(index, turns)

# %%
index = 30  # Change this to visualize different particles
turns = np.arange(900, 999)

compare_pred_act_x(index, turns)

# %%
def x_px_turns(turns_to_plot, index):
    fig, axes = plt.subplots(2, 5, figsize=(20, 8), sharex=True, sharey=True)
    for i, turn in enumerate(turns_to_plot):
        ax = axes[i // 5, i % 5]
        ax.plot(test[:, index, 0] * 1000, test[:, index, 2] * 1000, '.', markersize=1, color='C0', label='True')
        ax.plot(pred[index, :, 0] * 1000, pred[index, :, 2] * 1000, '.', markersize=1, color='C1', label='Predicted')
        ax.plot(test[turn, index, 0] * 1000, test[turn, index, 2] * 1000, 'o', markersize=5, color='C2', label=f'True: Particle {index}')
        ax.plot(pred[index, turn, 0] * 1000, pred[index, turn, 2] * 1000, 'o', markersize=5, color='C3', label=f'Predicted: Particle {index}')
        ax.set_title(f'Turn {turn}')
        ax.grid(True)
        if i % 5 == 0:
            ax.set_ylabel(r'$p_x$ [mm]')
        if i >= 5:
            ax.set_xlabel('x [mm]')

    handles, labels = axes[0, 0].get_legend_handles_labels()
    fig.legend(handles, labels, loc='upper right')
    plt.tight_layout()
    plt.show()

# %%
def y_py_turns(turns_to_plot, index):
    fig, axes = plt.subplots(2, 5, figsize=(20, 8), sharex=True, sharey=True)
    for i, turn in enumerate(turns_to_plot):
        ax = axes[i // 5, i % 5]
        ax.plot(test[:, index, 1] * 1000, test[:, index, 3] * 1000, '.', markersize=1, color='C0', label='True')
        ax.plot(pred[index, :, 1] * 1000, pred[index, :, 3] * 1000, '.', markersize=1, color='C1', label='Predicted')
        ax.plot(test[turn, index, 1] * 1000, test[turn, index, 3] * 1000, 'o', markersize=5, color='C2', label=f'True: Particle {index}')
        ax.plot(pred[index, turn, 1] * 1000, pred[index, turn, 3] * 1000, 'o', markersize=5, color='C3', label=f'Predicted: Particle {index}')
        ax.set_title(f'Turn {turn}')
        ax.grid(True)
        if i % 5 == 0:
            ax.set_ylabel(r'$p_y$ [mm]')
        if i >= 5:
            ax.set_xlabel('y [mm]')

    handles, labels = axes[0, 0].get_legend_handles_labels()
    fig.legend(handles, labels, loc='upper right')
    plt.tight_layout()
    plt.show()

# %%
def init_state_x_px(indices_to_label):
    plt.figure(figsize=(8, 6))
    plt.scatter(init_test[:, 0], init_test[:, 2], s=10, color='C0')

# indices_to_label = range(700,900)
    for idx in indices_to_label:
        plt.annotate(str(idx), (init_test[idx, 0], init_test[idx, 2]), fontsize=8, color='red')

    plt.xlabel('x')
    plt.ylabel('px')
    plt.title('Particles in (x, px) space - initial state')
    plt.grid()
    plt.show()

# %%
def init_state_y_py(indices_to_label):
    plt.figure(figsize=(8, 6))
    plt.scatter(init_test[:, 1], init_test[:, 3], s=10, color='C0')

# indices_to_label = range(700,900)
    for idx in indices_to_label:
        plt.annotate(str(idx), (init_test[idx, 1], init_test[idx, 3]), fontsize=8, color='red')

    plt.xlabel('y')
    plt.ylabel('py')
    plt.title('Particles in (y, py) space - initial state')
    plt.grid()
    plt.show()

# %%
turns_to_plot = np.arange(0, 500, 50)

# %%
indices_to_label = [300] # indices to label

init_state_x_px(indices_to_label)
x_px_turns(turns_to_plot, indices_to_label[0])

init_state_y_py(indices_to_label)
y_py_turns(turns_to_plot, indices_to_label[0])

# %%
indices_to_label = [10] # indices to label

init_state_x_px(indices_to_label)
x_px_turns(turns_to_plot, indices_to_label[0])

init_state_y_py(indices_to_label)
y_py_turns(turns_to_plot, indices_to_label[0])

# %%
indices_to_label = [501] # indices to label

init_state_x_px(indices_to_label)
x_px_turns(turns_to_plot, indices_to_label[0])

init_state_y_py(indices_to_label)
y_py_turns(turns_to_plot, indices_to_label[0])

# %%
# Plot position and momentum over turns
def compare_pred_act_y(index, turns):
    plt.figure(figsize=(12, 5))
    plt.subplot(2, 1, 1)
    plt.plot(test[turns, index, 1], label='y', color='C0')
    plt.plot(pred[index, turns, 1].squeeze(), label='Predicted y', linestyle='--', color='C1')
    plt.title(f'Particle {index} Position Over Turns')
    plt.ylabel('y')
    plt.grid()
    plt.legend()

    plt.subplot(2, 1, 2)
    plt.plot(test[turns, index, 3], label='py', color='C0')
    plt.plot(pred[index, turns, 3].squeeze(), label='Predicted py', linestyle='--', color='C1')
    plt.title(f'Particle {index} Momentum Over Turns')
    plt.xlabel('Turn')
    plt.ylabel('py')
    plt.grid()
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
index = 30  # Change this to visualize different particles
turns = np.arange(100)

compare_pred_act_y(index, turns)

# %%
index = 30  # Change this to visualize different particles
turns = np.arange(900, 999)

compare_pred_act_y(index, turns)

# %%
# pred: shape (num_particles, num_timesteps, 2)
# x_xp_test: shape (num_timesteps, num_particles, 2)
# Let's transpose x_xp_test to (num_particles, num_timesteps, 2) for comparison
x_xp_test_aligned = np.transpose(test, (1, 0, 2))

# Compute MSE at each time step for x and px separately
mse_x = np.mean((pred[:, :, 0] - x_xp_test_aligned[:, :, 0]) ** 2, axis=0)
mse_px = np.mean((pred[:, :, 2] - x_xp_test_aligned[:, :, 2]) ** 2, axis=0)
mse_y = np.mean((pred[:, :, 1] - x_xp_test_aligned[:, :, 1]) ** 2, axis=0)
mse_py = np.mean((pred[:, :, 3] - x_xp_test_aligned[:, :, 3]) ** 2, axis=0)

# Plot both on subplots
plt.figure(figsize=(12, 10))

plt.subplot(4, 1, 1)
plt.plot(mse_x, label='MSE x')
plt.xlabel('Time step')
plt.ylabel('MSE (x)')
plt.title('Mean Squared Error for x over Time Steps')
plt.grid()
plt.legend()

plt.subplot(4, 1, 2)
plt.plot(mse_px, label='MSE px', color='orange')
plt.xlabel('Time step')
plt.ylabel('MSE (px)')
plt.title('Mean Squared Error for px over Time Steps')
plt.grid()
plt.legend()

plt.subplot(4, 1, 3)
plt.plot(mse_y, label='MSE y', color='green')
plt.xlabel('Time step')
plt.ylabel('MSE (y)')
plt.title('Mean Squared Error for y over Time Steps')
plt.grid()
plt.legend()

plt.subplot(4, 1, 4)
plt.plot(mse_py, label='MSE py', color='red')
plt.xlabel('Time step')
plt.ylabel('MSE (py)')
plt.title('Mean Squared Error for py over Time Steps')
plt.grid()

plt.tight_layout()
plt.show()

# %%
# Load the loss arrays
train_loss = np.load('training_losses.npy')
val_loss = np.load('validation_losses.npy')

epochs = np.arange(1, len(train_loss) + 1)

plt.figure(figsize=(8, 5))
plt.plot(epochs, train_loss, label='Training Loss', color='C0')
plt.plot(epochs, val_loss, label='Validation Loss', color='C1', linestyle='--')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss vs Epochs')
plt.legend()
plt.grid()
plt.show()

# %%
import PyNAFF as pnf

# %%
# x
print(pnf.naff(test[:500, index, 0], turns=500, nterms=1, skipTurns=0, getFullSpectrum=False, window=1))
print(pnf.naff(test[500:, index, 0], turns=499, nterms=1, skipTurns=0, getFullSpectrum=False, window=1))
print(pnf.naff(pred[index, :500, 0].squeeze(), turns=500, nterms=1, skipTurns=0, getFullSpectrum=False, window=1))
print(pnf.naff(pred[index, 500:, 0].squeeze(), turns=499, nterms=1, skipTurns=0, getFullSpectrum=False, window=1))
# Out:
# [[ 0.          0.37913731  0.00607577  0.00525368 -0.00305186]]
# [[ 0.          0.3791373   0.00607415 -0.00604682  0.0005755 ]]
# [[ 0.          0.37856354  0.00589525  0.00498213 -0.00315156]]
# [[0.         0.37856269 0.00589687 0.00219783 0.00547199]]

# %%
# y
print(pnf.naff(test[:500, index, 3], turns=500, nterms=1, skipTurns=0, getFullSpectrum=False, window=1))
print(pnf.naff(test[500:, index, 3], turns=499, nterms=1, skipTurns=0, getFullSpectrum=False, window=1))
print(pnf.naff(pred[index, :500, 3].squeeze(), turns=500, nterms=1, skipTurns=0, getFullSpectrum=False, window=1))
print(pnf.naff(pred[index, 500:, 3].squeeze(), turns=499, nterms=1, skipTurns=0, getFullSpectrum=False, window=1))
# Out:
# [[ 0.00000000e+00  4.23730903e-01  5.12635242e-05  3.54378749e-05
#   -3.70419483e-05]]
# [[ 0.00000000e+00  4.23730894e-01  5.12635375e-05 -4.20477282e-06
#   -5.10908032e-05]]
# [[ 0.00000000e+00  4.24016116e-01  5.09577421e-05  3.67194340e-05
#   -3.53323456e-05]]
# [[ 0.00000000e+00  4.24016645e-01  5.09769266e-05  3.84644812e-05
#   -3.34534114e-05]]
